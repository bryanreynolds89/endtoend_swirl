# %% [markdown]
# ### Import Dependencies

# %%
import openai
import instructor
from qdrant_client import QdrantClient

from pydantic import BaseModel, Field

# %% [markdown]
# ### RAG Pipeline

# %%
client = instructor.from_openai(openai.OpenAI())

# %%
class RAGGenerationResponse(BaseModel):
    answer: str = Field(description="The answer to the question")

# %%
def get_embedding(text, model="text-embedding-3-small"):
    response = openai.embeddings.create(
        input=text,
        model=model,
    )

    return response.data[0].embedding


def retrieve_data(query, qdrant_client, k=5):

    query_embedding = get_embedding(query)

    results = qdrant_client.query_points(
        collection_name="Amazon-items-collection-00",
        query=query_embedding,
        limit=k,
    )

    retrieved_context_ids = []
    retrieved_context = []
    similarity_scores = []
    retrieved_context_ratings = []

    for result in results.points:
        retrieved_context_ids.append(result.payload["parent_asin"])
        retrieved_context.append(result.payload["description"])
        retrieved_context_ratings.append(result.payload["average_rating"])
        similarity_scores.append(result.score)

    return {
        "retrieved_context_ids": retrieved_context_ids,
        "retrieved_context": retrieved_context,
        "retrieved_context_ratings": retrieved_context_ratings,
        "similarity_scores": similarity_scores,
    }


def process_context(context):

    formatted_context = ""

    for id, chunk, rating in zip(context["retrieved_context_ids"], context["retrieved_context"], context["retrieved_context_ratings"]):
        formatted_context += f"- ID: {id}, rating: {rating}, description: {chunk}\n"

    return formatted_context


def build_prompt(preprocessed_context, question):

    prompt = f"""
You are a shopping assistant that can answer questions about the products in stock.

You will be given a question and a list of context.

Instructtions:
- You need to answer the question based on the provided context only.
- Never use word context and refer to it as the available products.

Context:
{preprocessed_context}

Question:
{question}
"""

    return prompt


def generate_answer(prompt):

    response, raw_response = client.chat.completions.create_with_completion(
        model="gpt-4.1-mini",
        messages=[{"role": "system", "content": prompt}],
        temperature=0,
        response_model=RAGGenerationResponse
    )

    return response


def rag_pipeline(question, qdrant_client, top_k=5):

    retrieved_context = retrieve_data(question, qdrant_client, top_k)
    preprocessed_context = process_context(retrieved_context)
    prompt = build_prompt(preprocessed_context, question)
    answer = generate_answer(prompt)

    final_result = {
        "datamodel": answer,
        "answer": answer.answer,
        "question": question,
        "retrieved_context_ids": retrieved_context["retrieved_context_ids"],
        "retrieved_context": retrieved_context["retrieved_context"],
        "similarity_scores": retrieved_context["similarity_scores"]
    }

    return final_result

# %%
qdrant_client = QdrantClient(url="http://localhost:6333")

# %%
output = rag_pipeline("Can I get a charging cable? Please suggest me a good one.", qdrant_client)

# %%
output
# Out:
# {'datamodel': RAGGenerationResponse(answer='Yes, you can get a charging cable. A good option available is the 20FT/6M Link Cable (ID: B09QY98TXK). It is a long cable that should provide ample length for charging and use.'),
#  'answer': 'Yes, you can get a charging cable. A good option available is the 20FT/6M Link Cable (ID: B09QY98TXK). It is a long cable that should provide ample length for charging and use.',
#  'question': 'Can I get a charging cable? Please suggest me a good one.',
#  'retrieved_context_ids': ['B0BWQYJY87',
#   'B09PVCVQDP',
#   'B09QY98TXK',
#   'B09Y8TFH8D',
#   'B0B1PM6D24'],
#  'retrieved_context': ['YOXXZUS Switch Charger,Switch AC Adapter Support TV Dock Mode for Switch OLED/Switch Lite 39W (15V 2.6A) 【Safe and Stable Charging】It takes about 2.5 hours to fully charge the SWITCH,short circuit protection, over current protection, surge protection, overload protection, etc. 【Support Switch TV Dock】This charger is compatible with the SWITCH TV dock,It works for docking the switch to play on TV.(Note:SWITCH LITE does not support TV projection) 【39W Switch AC Adapte】Designed for the Switch OLED/Switch Lite (15V 2.6A) .A great replacement charger or backup ac adapter for travel. 【5FT Charger Cable】Switch Charger come with an extra-long 5 Feet type C Integrated cable giving you plenty of cord to reach an outlet. High-quality cables ensure a long service life. 【Customer Service】Support 30 days return and refund,1 year replacement.If you encounter any problems after placing an order, you can contact us, and we will solve it for you as soon as possible.',
#   'HiBloks Magnetic Controllers Charging for Oculus Quest 2, Charging Dock Replacement Parts Kit for Oculus Quest 2 Accessories with 2 Rechergeable Batteries, Battery Cover and USB-C Charger Cable ✿✿No Disassembly & Magnetic Charging: This Quest 2 controller charging kit is professionally designed with a not need to be disassembled battery cover and a magnetic charging connector, and is equipped with a continuously rechargeable battery. This design allows you to avoid repeated disassembly and replacement of the battery, reduce the wear and tear of the controller, make you more comfortable to use ✿✿Work with Silicone Cover: Our set is equipped with a hole puncher, you can punch a hole in the silicone cover after replacing the battery, so that you can use the silicone cover when charge, avoid repeated disassembly of the silicone cover, to be better protect the controller and enhance your game enjoyment. ✿✿Effortless Charging: Just follow the steps to replace the battery cover, and then connect the magnetic charging cable to charge, so that your controller will never dies ✿✿Save Your Time & Money: This Oculus Quest 2 accessories can use the magnetic interface to charge, don’t waste time and money to swapping out batteries, save your time to experience more fun ✿✿Environmental Friendly: Different from other Oculus Quest 2 charger, we are equipped with rechargeable batteries, environmentally friendly, reusable, will not produce waste batteries and do not pollute the environment 【What You Will Get】2pcs rechargeable batteries, 2pcs battery cover(left & right), 1pc magnetic charging cable, 1pc hole puncher, 1pc card pin and HiBloks 24 hours after-sales service, if you are not Satisfied with the Quest 2 charging set for Any Reason, please feel free to contact us, we will do our best to answer you!',
#   '20FT/6M Link Cable ',
#   'Switch Organizer Station with Controller Charger, Wiilkac Portable TV Storage Tower Dock Compatible with Nintendo Switch/OLED Joycons, Pro Controller and Poke Ball Plus Controller Accessories 【ALL-IN-ONE Storage Stand & Charging Dock】: Designed to store and charge for 2 Nintendo Switch Pro controllers and 4 Joy Cons, your poke ball plus also can be charged at the switch charging station. Storing 12 game cards and 15 game card boxes at the same time. Two extra hooks on the side can hang two Pro controllers. Can meet your storage, charging and tidy needs. 【Keep Neat and Save Space】: This switch organizer stand can keep organized for joycons, controllers and for poke balls. Enables your all consoles and game card boxes in a vertical position. This switch tower organizer stand will help you save the space and display your favourite console well. You can store your games to keep them in order and within reach. It must be a perfect gift for Nintendo Switch gamer. 【Safe & Reliable】:This 6 in 1 switch charging dock has built-in intelligent protection chips. These are designed to prevent over-currents, over-heating, over-voltage, short-circuits, and as a precaution, it will never over charge. Durable Acrylic and ABS body ensures reliability. 【LED Indicator】: You can know the charging status through the indicator light, the red and green charging lights tell you that it is charging and fully charged. When connected to a charging power source, the charging light will turn green. 【Easy to install】: Only need a simple combination to get a multi-functional vertical switch organizer stand, please install it according to the installation method on the package. If any issue arrives, please feel free to contact us. Our after-sale service support team will offer help you to the best of our abilities!',
#   'Rechargeable Battery Packs for Xbox One Controller,4x2600mAh Xbox one Rechargeable Battery Packs, Rechargeable Batteries with Charging Dock for Xbox One/S/X/Xbox Series/S/X 20-25H Long-Lasting Xbox Rechargeable Battery Pack :Xbox one rechargeable battery pack comes with 4x2600mAh batteries and charger .Each battery can provide up to 25H playing time and charge 2000 times.The batteries really do last a lot longer than your typical ones .No more worrying about interrupting your game for swapping the battery. Rechargeable battery pack is widely compatible with Xbox Series X|S/ Xbox One/ Xbox One S / Xbox One X controller 5H Quick Charging Speed :xbox one controller battery charger support 4 batteries at the same time .It take about 5 hours to fully charge all the batteries . Three of our family members game regularly on the XBox, so we were going through a really sad amount of disposable batteries before we got xbox one controller rechargeable battery. Now 4x2600mAh rechargeable batteries for xbox one controller support our family to play time together and enjoy the fun of game Say Goodbye to AA Batteries :Need a lot of money to buy disposable batteries and have to deal with AA batteries all the time is a hassle, so it’s so nice to have rechargeable batteries. When one battery for xbox one runs out , you have three batteries waiting to be used. It keeps you gaming without interruption. Save a lots money and extend your game time after having 4 pcs rechargeable battery for xbox Cool Led Indicator Design： charger for rechargeable xbox one controller battery pack has a special design as cool as a spaceship. There is a cool “X” logo that projects underneath each station as a charging status indicator.Red light -in charging ,green light -fully charged . The charger has the ability to induce the orientation of batteries and alter the polarity automatically .No worry about inserting batteries wrongly .When not in use ,you are supposed to turn them upside down in the dock Built in Intelligent Safe Protection.charger for xbox series x controller battery pack with built in smart over-charged,over-current,over -voltage ,over-heated, short-circuit protection to keep battery life and make each battery to be recharged up to 2000 times. Xbox series x rechargeable battery pack with charger help us save a lot of money on buying more batteries and over-charge protection ensure safety even for over-night charging'],
#  'similarity_scores': [0.41708097,
#   0.36002815,
#   0.3389576,
#   0.32764608,
#   0.32020062]}

# %%
print(output["answer"])
# Out:
# Yes, you can get a charging cable. A good option available is the 20FT/6M Link Cable (ID: B09QY98TXK). It is a long cable that should provide ample length for charging and use.

# %% [markdown]
# ### RAG Pipeline with Grounding Context

# %%
class RAGUsedContext(BaseModel):
    id: str = Field(description="The ID of the item used to answer the question")
    description: str = Field(description="Short description of the item used to answer the question")

class RAGGenerationResponse(BaseModel):
    answer: str = Field(description="The answer to the question")
    references: list[RAGUsedContext] = Field(description="List of items used to answer the question")

# %%
def get_embedding(text, model="text-embedding-3-small"):
    response = openai.embeddings.create(
        input=text,
        model=model,
    )

    return response.data[0].embedding


def retrieve_data(query, qdrant_client, k=5):

    query_embedding = get_embedding(query)

    results = qdrant_client.query_points(
        collection_name="Amazon-items-collection-00",
        query=query_embedding,
        limit=k,
    )

    retrieved_context_ids = []
    retrieved_context = []
    similarity_scores = []
    retrieved_context_ratings = []

    for result in results.points:
        retrieved_context_ids.append(result.payload["parent_asin"])
        retrieved_context.append(result.payload["description"])
        retrieved_context_ratings.append(result.payload["average_rating"])
        similarity_scores.append(result.score)

    return {
        "retrieved_context_ids": retrieved_context_ids,
        "retrieved_context": retrieved_context,
        "retrieved_context_ratings": retrieved_context_ratings,
        "similarity_scores": similarity_scores,
    }


def process_context(context):

    formatted_context = ""

    for id, chunk, rating in zip(context["retrieved_context_ids"], context["retrieved_context"], context["retrieved_context_ratings"]):
        formatted_context += f"- ID: {id}, rating: {rating}, description: {chunk}\n"

    return formatted_context


def build_prompt(preprocessed_context, question):

    prompt = f"""
You are a shopping assistant that can answer questions about the products in stock.

You will be given a question and a list of context.

Instructtions:
- You need to answer the question based on the provided context only.
- Never use word context and refer to it as the available products.
- As an output you need to provide:

* The answer to the question based on the provided context.
* The list of the IDs of the chunks that were used to answer the question. Only return the ones that are used in the answer.
* Short description (1-2 sentences) of the item based on the description provided in the context.

- The short description should have the name of the item.
- The answer to the question should contain detailed information about the product and returned with detailed specification in bullet points.

Context:
{preprocessed_context}

Question:
{question}
"""

    return prompt


def generate_answer(prompt):

    response, raw_response = client.chat.completions.create_with_completion(
        model="gpt-4.1-mini",
        messages=[{"role": "system", "content": prompt}],
        temperature=0,
        response_model=RAGGenerationResponse
    )

    return response


def rag_pipeline(question, qdrant_client, top_k=5):

    retrieved_context = retrieve_data(question, qdrant_client, top_k)
    preprocessed_context = process_context(retrieved_context)
    prompt = build_prompt(preprocessed_context, question)
    answer = generate_answer(prompt)

    final_result = {
        "original_ouput": answer,
        "answer": answer.answer,
        "references": answer.references,
        "question": question,
        "retrieved_context_ids": retrieved_context["retrieved_context_ids"],
        "retrieved_context": retrieved_context["retrieved_context"],
        "similarity_scores": retrieved_context["similarity_scores"]
    }

    return final_result

# %%
result = rag_pipeline("Can I get some earphones?", qdrant_client, top_k=10)

# %%
result
# Out:
# {'original_ouput': RAGGenerationResponse(answer='Yes, you can get earphones in the form of wireless gaming earbuds. The MORMOQUE T2 Wireless Gaming Earbuds offer the following features:\n\n- 45ms Low Latency Combat Mode for gaming\n- Wireless earbuds with microphone\n- IPX5 Waterproof rating\n- 30 hours total playtime with the charging case\n- Hi-Fidelity Stereo Sound quality with punchy bass\n- Touch control ergonomic earbuds\n- Fast charging with Type-C, providing 100 minutes of playtime in just 10 minutes of charging\n- ENC microphone with noise reduction for clear voice transmission\n- Breath LED light decoration\n\nThese earbuds are suitable for gaming and general use with a strong battery life and good sound quality.', references=[RAGUsedContext(id='B0BRV29L6C', description='MORMOQUE T2 Wireless Gaming Earbuds, 45ms Low Latency Combat Mode, Wireless Earbuds with Microphone, IPX5 Waterproof，with 30H Playtime Gaming Mode-Gaming Wireless Headphones with Ultra-Low Latency; Hi-Fidelity Stereo Sound quality with Punchy Bass; Massive 30Hrs Total Playtime with the Charging Case; Touch Control Ergonomic Earbuds Battery-The massive battery power of 30 hrs playtime lets you explore all your entertainment without worrying about putting them on charge. Fast charging-Type-C super-fast charging gives you 100 mins of playtime in just 10 mins of charging. You don’t have to impatiently wait for long anymore. ENC Mic-In-line built microphone with ENC function which will reduce back ground noise and transfer clear voice during talking Breath LED light-Breath LED lights decrates the headphones amazing and high-end')]),
#  'answer': 'Yes, you can get earphones in the form of wireless gaming earbuds. The MORMOQUE T2 Wireless Gaming Earbuds offer the following features:\n\n- 45ms Low Latency Combat Mode for gaming\n- Wireless earbuds with microphone\n- IPX5 Waterproof rating\n- 30 hours total playtime with the charging case\n- Hi-Fidelity Stereo Sound quality with punchy bass\n- Touch control ergonomic earbuds\n- Fast charging with Type-C, providing 100 minutes of playtime in just 10 minutes of charging\n- ENC microphone with noise reduction for clear voice transmission\n- Breath LED light decoration\n\nThese earbuds are suitable for gaming and general use with a strong battery life and good sound quality.',
#  'references': [RAGUsedContext(id='B0BRV29L6C', description='MORMOQUE T2 Wireless Gaming Earbuds, 45ms Low Latency Combat Mode, Wireless Earbuds with Microphone, IPX5 Waterproof，with 30H Playtime Gaming Mode-Gaming Wireless Headphones with Ultra-Low Latency; Hi-Fidelity Stereo Sound quality with Punchy Bass; Massive 30Hrs Total Playtime with the Charging Case; Touch Control Ergonomic Earbuds Battery-The massive battery power of 30 hrs playtime lets you explore all your entertainment without worrying about putting them on charge. Fast charging-Type-C super-fast charging gives you 100 mins of playtime in just 10 mins of charging. You don’t have to impatiently wait for long anymore. ENC Mic-In-line built microphone with ENC function which will reduce back ground noise and transfer clear voice during talking Breath LED light-Breath LED lights decrates the headphones amazing and high-end')],
#  'question': 'Can I get some earphones?',
#  'retrieved_context_ids': ['B0BRV29L6C',
#   'B09ZQ4FG91',
#   'B09Y3PTLK3',
#   'B09SKNHGQ5',
#   'B09V7G7YY4',
#   'B09T5BB1X3',
#   'B09QY98TXK',
#   'B0BCNYBQ38',
#   'B0B9GM9MF9',
#   'B0B1WC6CZ2'],
#  'retrieved_context': ['MORMOQUE T2 Wireless Gaming Earbuds, 45ms Low Latency Combat Mode, Wireless Earbuds with Microphone, IPX5 Waterproof，with 30H Playtime Gaming Mode-Gaming Wireless Headphones with Ultra-Low Latency; Hi-Fidelity Stereo Sound quality with Punchy Bass; Massive 30Hrs Total Playtime with the Charging Case; Touch Control Ergonomic Earbuds Battery-The massive battery power of 30 hrs playtime lets you explore all your entertainment without worrying about putting them on charge. Fast charging-Type-C super-fast charging gives you 100 mins of playtime in just 10 mins of charging. You don’t have to impatiently wait for long anymore. ENC Mic-In-line built microphone with ENC function which will reduce back ground noise and transfer clear voice during talking Breath LED light-Breath LED lights decrates the headphones amazing and high-end',
#   'Turtle Beach Stealth 600 Gen 2 MAX Wireless Multiplatform Amplified Gaming Headset for Xbox Series X|S, Xbox One, PS5, PS4, Nintendo Switch, PC, and Mac with 48+ Hour Battery – Teal Compatible with Xbox, PlayStation, Nintendo Switch, and PC Massive 48+ Hour Battery Life Officially Licensed by Microsoft for Xbox Proprietary, Lag-free 2.4GHz Wireless Connection Tuned for Immersive Surround Sound 50mm Speakers for Powerful, Amplified Audio Gen 2 Mic for Clear chat with Teammates Comfortable, Glasses-Friendly Ear Cushions Turtle Beach Exclusive Superhuman Hearing Strengthened Headband and Hinge Design',
#   'YLYXCCH Audio Adapter for Wireless Bluetooth Xbox One Stereo Headset Audio Adapter for Xbox One X/S Compatible with Wireless Headset Speakers Audio Mic Headphone Converter Sound Enhancer ★Bluetooth Stereo Audio Adapter：This bluetooth headset adapter fits any version of bluetooth stereo Headset ,Speakers,Make sure your controller have 3.5mm headphone jack（Not compatible with Airpods.）. ★Support Voice chat ： support voice chat on/off，NOTE: The built-in microphone is omnidirectional and has high sensitivity. When you turn on the microphone, the sound of pressing the buttons of the gamepad will also be recorded. This phenomenon is normal.Please mute the microphone when not chat ★Smaller and Stronger:YLYXCCH Using the latest technologies, smaller and stronger than others. No delay and larger transmission range, stable transmission. Have fun with your friends. ★controller：Extremely small size and lightweight for portable use, fast pair and automatically re-pair with the last paired device. 15 meters barrier-free transmission without any loss ★Easy to Use：Just set your earphone to bluetooth pairing status and hold the paring button of the adapter for 5 second,once connection is successful, plug this bluetooth audio transmitter to controller.',
#   "VR Headset, 3D Virtual Reality Headset VR Accessories for Movies and Games VR Glasses for iPhone & Android Phone,Best Virtual Reality Goggles ❥COMPATIBILITY ❤ VR Glasses can fit for most non-curved smartphones with screen sizes from 5 ~ 7 inch compatible with iPhone 6, iPhone 6 Plus, -iPhone 7, iPhone 7 Plus, iPhone 8, iPhone X,iPhone12, iPhone12 pro, iPhone12 pro max, Samsung Galaxy, Xperia, LG, Xiaomi, One Plus, Moto and more. ❥Ergonomic Design❤ This adjustable headband strap is made of lightweight material, which can decrease the pressure around your eyes, face and on your head, providing you more comfortable feeling. What’s more, the nose area is deepened, reducing the pressure on your nose. The open front cover on both sides helps dissipate heat, keeping you cool while enjoying the virtual world. ❥user experience ❤ Unique dual lens design, pupil distance and object distance adjustment are available for myopic population. The glasses support naked eye viewing with myopia 0-800 degrees and direct vision with myopia glasses. After wearing it, please adjust the left (right) pupil distance to suit yourself.(can also wear myopia glasses,to add a better experience for myopia users) ❥More Virtual Reality Videos❤ This VR Headset with Remote Controller, needs to be used with smartphones,Please download VR videos on your mobile phone before use.All VR requires left-right format 3D effect videos,you can download VR relevant apps from Google Play Store or Apple Store. ❥best holiday gift❤ Premium VR set present for father's day, Halloween, Easter, Christmas, Black Friday, Cyber Monday sale.It can bring different fun to your family and friends.",
#   "Light up Headphone Controller Holder, 16 Colors 3D LED Lights Gamepad Headset Stand, Game Controller Hanger for All Universal Gaming PC Accessories 👍NOT ONLY a STAND: Multi advanced all-round stand: controller holder+headset stand+...---all universal models can be perfectly stored or displayed.Excellent stable and flexible, compatibility with your stylish interiors and digital home appliances , so it not only a stand but also a night light. 👍Creative 3D Visual Effect: This is a 3D illusion lamp that can show up the gamepad when it lights up, with an optical acrylic flat board with laser engraving can give you amazing 3D visual effect. 3D is just visual, the light itself is flat. It's bound to amaze and impress your kids and guests. It is a unique birthday, Christmas, or Easter gift for kids or friends, controller decorations for home. 👍Convenient and Safe: The 3D gamepad night light could use USB to connect or 3 x AAA batteries (not included) to power. The light source uses high-quality LED, which is soft and uniform, no dazzling, non-flicker, dimmable, harmless to children's eyes, provides children sweet and warm night. 👍Easy Installation&Use: The environmental protection design allows you to install it without tools. Just takes 1 minute to hang up your favorite controllers, switches, or headphones. 👍100% Satisfaction Guaranty Support: We aim to provide 100% good holders for you, return or refund are protected if the light-up stand doesn't meet your need.",
#   'Headphone Hook Holder Stand & Gamepad Controller Stand for PS5, Xbox Series X, Screwless Portable Storage Rack Accessories - Black 【Universal Compatibility】 This is a headset holder that can be mounted on the game console, Designed for Sony Playstation 5、Xbox Series X console. No screws & no tape. Engineering design with the ABS plastics, durable and long lasting. 【Removable Controller Holder & Headphone Stand 2 in 1】Hang all your controllers and headphones neatly and conveniently out of the way, keeps your headphones organized and easy to reach, save your desk spaces, tidy and easy to find. 【Small and Simple】 If you have your Xbox Series X and PS5 console on a desk, this game controller and black headphones holder will take less desk space compared to a separate headphones stand. Super easy to install, keeps your desk clean and organized, great price! 【Easy to Install】Simply put the storage hangers on your console, then you get place for your controllers immediately. Looking stylish and held securely. 【Guarantee and 60-Days Money Back Policy】 We promise maximum protection for the life of our product. Also, 24*7day customer service to solve the problem rapidly. If you have any issue, please feel free to contact us.',
#   '20FT/6M Link Cable ',
#   '60% Wireless Mechanical Keyboard, Triple Mode 2.4G/Type-C/Bluetooth Mechanical Keyboard, Low Profile, Rainbow Backlit, Blue Switch, 63 Keys Portable Mini Wireless Gaming Keyboard for PC/Mac, White 【Wireless+Bluetooth+Wired】The wireless mechanical keyboard has 3 connection modes: wireless mode for lag-free operation, Bluetooth for efficient power consumption, and the detachable USB-C cable charges while in use. can be connected to PC, laptop, iPad, mobile phone, up to 5 devices to double the office efficiency. 【40% Ultra-Thin Low Profile】The thickness is 2.2cm, which is only 60% of the ordinary keyboard. RisoPhy bluetooth gaming keyboard with a shorter pre-travel and total travel distance that triggers an input and feedback faster than conventional/normal-profile mechanical switches. 【Classic 63 Keys Compact Design】This wireless mechanical keyboard adopts a compact 63-key layout, removes the numeric keypad and F-key row, and retains the arrow keys to provide more desktop space. The size is only 31*13.5*3cm, and the weight is 467g, you can easily put it in a bag and carry it out. 【Gorgeous Rainbow LED Backlit】20 LED Rainbow Backlight Effects, 5 brightness levels & speeds, the compact design of the wireless mechanical keyboard makes the transition of various lighting effects softer and more natural. The keycaps are backlit, make the each key more brilliant, making it easier to find your keys in the dark. 【Rechargeable Battery】This bluetooth gaming keyboard has 360 hours of standby time and can be used continuously for 10 hours with lights on. It also comes with a power switch and a 30-minute sleep mode to save power. You can charge it anytime with the included Type-C cable. (✅Note: Lowering the brightness of the keypad can improve battery life.) 【Strong Compatibility & VIP Service】Plug and play, no drivers or software required.Work perfectly for Windows 11/10/8/7/XP, Mac OS, and Windows VISTA. Every product from RisoPhy will enjoy lifetime care. If your mechanical keyboard has any problem, all you need to do is contact our team (click on the store name).',
#   "DIERYA DK63 60% Wireless Mechanical Gaming Keyboard, RGB Backlit with Arrow Keys Wired Bluetooth Keyboard, 63 Keys Compact Mini Keyboard Full Key Programmable, Easy to Carry on Trip -Blue Switch ✅【Ultra-compact layout】: This 60% percent keyboard has an ultra-compact layout of 63 keys to keep, with arrow keys It is more convenient to operate than other 60 percent keyboard mechanical. suitable for all environments, business travel, gaming, office, home use, because its mini size is very easy to carry. ✅【Wired & Wireless Gaming Keyboard】：Connects with up to 3 devices via Bluetooth and switch among them easily. Features Bluetooth 5.1 to connect your smartphone, laptop and iPad at the same time, easily switching between them. It also has wired mode with USB Type-C connection. ✅【Cool RGB Backlight Effect】: Our RGB keyboard has 4 brightness lighting levels, 19 RGB backlight modes, 8 monochrome backlight modes. You can customize lighting effects through software, with up to 16.8 million lighting colors. These modes give you more fun when you're gaming or typing at night. ✅【1900mAh Battery】: The DK63 mechanical gaming keyboard with a battery capacity of 1900mAh，lasts up to 60 hours (tested with static RGB lighting), or up to 5 days of normal use (8 hrs/day) ✅【Compatibility and Reliable Service】: This DK63 wired and wireless keyboard is compatible with Windows / MacOS / Android.Our products are backed by a 12-month warranty, if you need help, please contact us, we will serve you promptly.",
#   'Wabracket Dust-proof kits for PS5, with Console Dust Protection Cover , 2pcs Dust Filters , 8 dust-proof silicone plugs . Detachable Dust Kits for PS5 Digital & Disk Version(1Pack) Dust Cover for PS5 -- Dust cover specially designed for PS5 to protect the console from dust, scratches, stains. The design with black and white edges makes the overall look simple and generous. NOTE: Please remove the dust case cover when using to avoid overheating and damage to the console. Dust-Proof Filters without Glue Residue -- Comes with dust filters for the PS55 digital and Disk version, please select the correct version when using it. Can avoid the entry of dust, insects and hair, just tear off the tape on the back of the PS5 filter, and then find the corresponding position and paste it. We use double-sided tape with no residue, so there is no need to worry about residue after removing it. Port Dust-Proof Silicone Plugs and Storage Line -- Take the 8 dust proof silicone plugs to the corresponding HDMI,USB,power supply sockets and other interfaces to protect your beloved PS5 from dust entering the port, and if they are not in use, you can use the included storage line to string them together for easy reuse next time. Easy to Install -- No tedious installation steps, just take up your precious minutes to make your PS5 better protected. What’s in the Package -- PS5 dust cover*1 , Dust-Proof filters*2 , Port Silicone Plugs*8 , StorageLine*1'],
#  'similarity_scores': [0.40778035,
#   0.31367236,
#   0.31149366,
#   0.29554123,
#   0.26610756,
#   0.25617215,
#   0.24506217,
#   0.24496248,
#   0.23194465,
#   0.23121831]}

# %%
print(result["answer"])
# Out:
# Yes, you can get earphones in the form of wireless gaming earbuds. The MORMOQUE T2 Wireless Gaming Earbuds offer the following features:
#
# - 45ms Low Latency Combat Mode for gaming
# - Wireless earbuds with microphone
# - IPX5 Waterproof rating
# - 30 hours total playtime with the charging case
# - Hi-Fidelity Stereo Sound quality with punchy bass
# - Touch control ergonomic earbuds
# - Fast charging with Type-C, providing 100 minutes of playtime in just 10 minutes of charging
# - ENC microphone with noise reduction for clear voice transmission
# - Breath LED light decoration
#
# These earbuds are suitable for gaming and general use with a strong battery life and good sound quality.
